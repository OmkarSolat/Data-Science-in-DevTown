# %% [markdown]
# <a href="https://colab.research.google.com/github/OmkarSolat/Data-Science-in-DevTown/blob/main/DAY7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # THE ACTIVITY DAY

# %% [markdown]
# DAY1->
# Compiler & INtrepreter, Python (Overview), Variables, Naming Conventions, Comments,
# Operators - Arit, Logical, Assignmet, Boolen, type function, concatenation, Colab features
#
#
#
# DAY2->
# String methods - Capitalize(), len(), upper(), lower(), startswith(), endswith(), replace(), count(),
# center(). Indexing & Slicing, input(), type casting, intro to Data Structures
#
#
#
# DAY3->
# List, properties of list, CRUD operations, list methods -> len(), sort(), append(), copy(), extend(), clear(),
# insert(), del (keyword), pop(), remove(), max(), min(), reverse(), sum(), list in a list, count()
#
#
#
# DAY4->
# Tuple, properties of tuple, CRUD operation, tuple to list conversion, adding tuple into tuple, count & index method,
# Dictionary, properties, CRUD operation, dict methods -> get(), update(), popitems(), pop(), fromkeys(),
# items(), copy(), clear, keys, values, dict in a dict
#
#
#
# DAY5->
# Sets, properties, CRUD operation, set methods -> add(), discard(), remove(), union(), intersection(), difference,
# issubset, issuperset, isdisjoint, isalpha & isnumeric & isalnum, symmetric_difference.
# Conditional Statements - if, elif, else,  logical operators, try & except
#
#
#
# DAY6->
# Loops -> For & while. List Comprehension, Nested Loops & its complexity (Time & Space), zip(), knowledge of
# automation L. Nested CS

# %% [markdown]
# Q1. Your teacher caught you and your friend for not paying attention in the class, so she decided to punish both of you. She tells you both to write "I will pay attention in the class from now onwards", 9000 times. Your friend don't know coding so he wrote the statement 9000 time in a usual way but since you are a programmer, you use programming to get the work done. How will you do it?

# %%
for i in range(9000):
   print("I will pay attention in the class from now onwards")
# Out:
# Streaming output truncated to the last 5000 lines.
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# ...

# %%
print("I will pay attention in the class from now onwards\n"*10)
# Out:
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards
# I will pay attention in the class from now onwards

# %% [markdown]
# Q2. Take an input from the user and print the factorial of that number. Note: A factorial is a function that multiplies a number by every number below it. For example 5!= 5*4*3*2*1=120.

# %%
num = int(input("Enter a number: "))
var = 1

for i in range(1,num+1):
  if num < 0:
     print("Invalid Input")
  elif num == 0 or num == 1:
     print("The factorial of",num,"is 1")
  else:
     var = var*i

print(var)
# Out:
# Enter a number: 5
# 120

# %%
num = int(input("Enter a number: "))
var = 1

while num > 0:
  var = var*num
  num = num-1

print(var)
# Out:
# Enter a number: 5
# 120

# %% [markdown]
# Q3. You are given a string and your task is to swap cases. In other words, convert all lowercase letters to uppercase letters and vice versa.
#
# For Example:
#
# Www.HackerRank.com → wWW.hACKERrANK.COM
#
# Pythonist 2 → pYTHONIST 2

# %%
var = "wWW.hACKERrANK.COM"
for i in var:
  if i.isupper():
    print(i.lower(),end="")
  else:
    print(i.upper(),end="")
# Out:
# Www.HackerRank.com

# %%
print(input().swapcase())
# Out:
# mission cds AND afcat
# MISSION CDS and AFCAT

# %% [markdown]
# Q4. Given a string, write a python function to check if it is palindrome or not. A string is said to be palindrome if the reverse of the string is the same as string. For example, “radar” is a palindrome, but “radix” is not a palindrome.

# %%
var = input().lower()
var1 = reversed(var)

print(var)
print(var1)

if var == var1:
  print("Palindrome")
else:
  print("Not a Palindrome")
# Out:
# radar
# radar
# ...
# Not a Palindrome

# %%
var = input().lower()
# var1 = reversed(var)
var1 = var[::-1]

print(var)
print(var1)

if var == var1:
  print("Palindrome")
else:
  print("Not a Palindrome")
# Out:
# Mom
# mom
# mom
# Palindrome

# %% [markdown]
# Q5. Make a two-player Rock-Paper-Scissors game. (Hint: Ask for player plays (using input), compare them, print out a message of congratulations to the winner)
#
# Remember the rules:
#
# Rock beats scissors -> R(r) beats S(s)
#
# Scissors beats paper -> S(s) beats P(p)
#
# Paper beats rock -> P(p) beats R(r)

# %%
series = int(input("Enter the rounds: "))

player1_arr = 0
player2_arr = 0

for i in range(series):
  player1 = input("Enter your choice (R,S,P):").upper()
  player2 = input("Enter your choice (R,S,P):").upper()

  if player1 == player2:
    print("Draw")
  elif (player1 == "R" and player2 == "S") or (player1 == "S" and player2 == "P") or (player1 == "P" and player2 == "R"):
    print("Player 1 wins!")
    player1_arr += 1
  else:
    player2_arr += 1
    print("Player 2 wins!")


if player1_arr > player2_arr:
  print("Player 1 won the series")
elif player1_arr < player2_arr:
  print("Player 2 won the series")
else:
  print("The series is a tie")
# Out:
# Enter the rounds: 5
# Enter your choice (R,S,P):r
# Enter your choice (R,S,P):p
# Player 2 wins!
# Enter your choice (R,S,P):s
# Enter your choice (R,S,P):p
# Player 1 wins!
# Enter your choice (R,S,P):r
# Enter your choice (R,S,P):p
# Player 2 wins!
# Enter your choice (R,S,P):s
# Enter your choice (R,S,P):p
# Player 1 wins!
# Enter your choice (R,S,P):s
# Enter your choice (R,S,P):r
# Player 2 wins!
# Player 2 won the series
