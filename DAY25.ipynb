# %% [markdown]
# <a href="https://colab.research.google.com/github/OmkarSolat/Data-Science-in-DevTown/blob/main/DAY25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Data Exploration

# %%
student_marks = {"Name":["Omkar", "Rohit", "Virat", "Sahil", "Arif","Aditya"],
                 "OS":[25, 75, 96, 65, 100,77],
                 "IOT":[20, 80, 60, 50, 99,100]}

df1 = pd.DataFrame(student_marks)

# %%
df1
# Out:
#      Name   OS  IOT
# 0   Omkar   25   20
# 1   Rohit   75   80
# 2   Virat   96   60
# 3   Sahil   65   50
# 4    Arif  100   99
# 5  Aditya   77  100

# %%
data = {"Apples":[102, 500, 250, 75],"Grapes":[50, 150, 90, 45],"Oranges":[55,88,99,77]}
df2 = pd.DataFrame(data,index=["A", "B", "C", "D"])

# %%
df2
# Out:
#    Apples  Grapes  Oranges
# A     102      50       55
# B     500     150       88
# C     250      90       99
# D      75      45       77

# %% [markdown]
# * head()

# %%
df1.head()              # head shows top 5 rows/datapoints
# Out:
#     Name   OS  IOT
# 0  Omkar   25   20
# 1  Rohit   75   80
# 2  Virat   96   60
# 3  Sahil   65   50
# 4   Arif  100   99

# %%
df1.head(3)
# Out:
#     Name  OS  IOT
# 0  Omkar  25   20
# 1  Rohit  75   80
# 2  Virat  96   60

# %% [markdown]
# * tail()

# %%
df1.tail()             # tail shows bottom 5 rows/datapoints
# Out:
#      Name   OS  IOT
# 1   Rohit   75   80
# 2   Virat   96   60
# 3   Sahil   65   50
# 4    Arif  100   99
# 5  Aditya   77  100

# %%
df1.tail(3)
# Out:
#      Name   OS  IOT
# 3   Sahil   65   50
# 4    Arif  100   99
# 5  Aditya   77  100

# %% [markdown]
# * dtypes

# %%
df1.dtypes
# Out:
# Name    object
# OS       int64
# IOT      int64
# dtype: object

# %% [markdown]
# * empty

# %%
df1.empty
# Out:
# False

# %%
df2.empty
# Out:
# False

# %% [markdown]
# * ndim

# %%
df1.ndim
# Out:
# 2

# %%
df2.ndim
# Out:
# 2

# %% [markdown]
# * shape

# %%
df1.shape
# Out:
# (6, 3)

# %%
df2.shape
# Out:
# (4, 3)

# %% [markdown]
# * size

# %%
df1.size
# Out:
# 18

# %%
df2.size
# Out:
# 12

# %% [markdown]
# * values

# %%
df1.values
# Out:
# array([['Omkar', 25, 20],
#        ['Rohit', 75, 80],
#        ['Virat', 96, 60],
#        ['Sahil', 65, 50],
#        ['Arif', 100, 99],
#        ['Aditya', 77, 100]], dtype=object)

# %% [markdown]
# * keys

# %%
df1.keys
# Out:
# <bound method NDFrame.keys of      Name   OS  IOT
# 0   Omkar   25   20
# 1   Rohit   75   80
# 2   Virat   96   60
# 3   Sahil   65   50
# 4    Arif  100   99
# 5  Aditya   77  100>

# %% [markdown]
# * describe()

# %%
df1.describe()
# Out:
#                OS         IOT
# count    6.000000    6.000000
# mean    73.000000   68.166667
# std     27.003703   31.051033
# min     25.000000   20.000000
# 25%     67.500000   52.500000
# 50%     76.000000   70.000000
# 75%     91.250000   94.250000
# max    100.000000  100.000000

# %%
df2.describe()
# Out:
#            Apples     Grapes    Oranges
# count    4.000000    4.00000   4.000000
# mean   231.750000   83.75000  79.750000
# std    194.676441   48.54122  18.786076
# min     75.000000   45.00000  55.000000
# 25%     95.250000   48.75000  71.500000
# 50%    176.000000   70.00000  82.500000
# 75%    312.500000  105.00000  90.750000
# max    500.000000  150.00000  99.000000

# %% [markdown]
# * T ->(Transpose)

# %%
df1.T
# Out:
#           0      1      2      3     4       5
# Name  Omkar  Rohit  Virat  Sahil  Arif  Aditya
# OS       25     75     96     65   100      77
# IOT      20     80     60     50    99     100

# %%
df1.iloc[[2]]
# Out:
#     Name  OS  IOT
# 2  Virat  96   60

# %% [markdown]
# * sum()

# %%
df1
# Out:
#      Name   OS  IOT
# 0   Omkar   25   20
# 1   Rohit   75   80
# 2   Virat   96   60
# 3   Sahil   65   50
# 4    Arif  100   99
# 5  Aditya   77  100

# %%
df1.sum()        # axis is by default 0
# Out:
# Name    OmkarRohitViratSahilArifAditya
# OS                                 438
# IOT                                409
# dtype: object

# %%
df1['OS'].sum()
# Out:
# 438

# %%
df1.sum(1)             # 1 is a axis
# Out:
# <ipython-input-55-4c75d4ddbb73>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.sum(1)             # 1 is a axis
# 0     45
# 1    155
# 2    156
# 3    115
# 4    199
# 5    177
# dtype: int64

# %% [markdown]
# * mean()

# %%
df1.mean()
# Out:
# <ipython-input-56-00fb6bfec183>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.mean()
# OS     73.000000
# IOT    68.166667
# dtype: float64

# %%
df1.mean(1)
# Out:
# <ipython-input-57-147b90ec4ba1>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean(1)
# 0    22.5
# 1    77.5
# 2    78.0
# 3    57.5
# 4    99.5
# 5    88.5
# dtype: float64

# %% [markdown]
# * median()

# %%
df1.median()
# Out:
# <ipython-input-58-e41201014d8f>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.median()
# OS     76.0
# IOT    70.0
# dtype: float64

# %%
df1.median(1)
# Out:
# <ipython-input-59-4f3820f67071>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.median(1)
# 0    22.5
# 1    77.5
# 2    78.0
# 3    57.5
# 4    99.5
# 5    88.5
# dtype: float64

# %% [markdown]
# * mode()

# %%
df1
# Out:
#      Name   OS  IOT
# 0   Omkar   25   20
# 1   Rohit   75   80
# 2   Virat   96   60
# 3   Sahil   65   50
# 4    Arif  100   99
# 5  Aditya   77  100

# %%
df1.mode()
# Out:
#      Name   OS  IOT
# 0  Aditya   25   20
# 1    Arif   65   50
# 2   Omkar   75   60
# 3   Rohit   77   80
# 4   Sahil   96   99
# 5   Virat  100  100

# %%
df2
# Out:
#    Apples  Grapes  Oranges
# A     102      50       55
# B     500     150       88
# C     250      90       99
# D      75      45       77

# %%
df2.mode()
# Out:
#    Apples  Grapes  Oranges
# 0      75      45       55
# 1     102      50       77
# 2     250      90       88
# 3     500     150       99

# %% [markdown]
# * std() ->standard deviation

# %%
df1.std()
# Out:
# <ipython-input-69-1c22e8bf5753>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.std()
# OS     27.003703
# IOT    31.051033
# dtype: float64

# %%
df1.std(1)
# Out:
# <ipython-input-70-e83e67c6bf93>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.std(1)
# 0     3.535534
# 1     3.535534
# 2    25.455844
# 3    10.606602
# 4     0.707107
# 5    16.263456
# dtype: float64

# %% [markdown]
# * min()   &   max()

# %%
df1.min()
# Out:
# Name    Aditya
# OS          25
# IOT         20
# dtype: object

# %%
df1.min(1)
# Out:
# <ipython-input-73-a0754e203f64>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.min(1)
# 0    20
# 1    75
# 2    60
# 3    50
# 4    99
# 5    77
# dtype: int64

# %%
df1.max()
# Out:
# Name    Virat
# OS        100
# IOT       100
# dtype: object

# %% [markdown]
# # Data manipulation

# %%
import pandas as pd
import numpy as np

# %%
data1 = np.random.randn(10,3)
data2 = np.random.randn(7,3)

# %%
df1 = pd.DataFrame(data1,columns=['col1','col2','col3'])
df2 = pd.DataFrame(data2,columns=['col1','col2','col3'])

# %%
df1
# Out:
#        col1      col2      col3
# 0 -0.206500 -1.160823 -0.772992
# 1  1.163203 -2.917620 -0.297502
# 2 -0.269615 -1.262359 -1.370471
# 3 -0.223231 -0.133734  0.619062
# 4 -0.265080  1.750913  0.606281
# 5 -0.837831  0.892757  0.389634
# 6 -1.876066  1.441248  1.607121
# 7 -0.347523  0.958160  0.505948
# 8  1.525707  0.635860  1.355359
# 9 -0.175594  0.015363  0.808664

# %%
df2
# Out:
#        col1      col2      col3
# 0  0.836250  0.070844 -1.074358
# 1  1.333872 -0.793309  0.690900
# 2 -0.590368 -0.548526 -0.314953
# 3  1.840619 -0.380707  1.198195
# 4  0.664352  0.492206 -0.266762
# 5 -0.570906  1.100950  0.772477
# 6  0.077875 -1.150067 -1.477893

# %%
df3 = pd.concat([df1,df2],ignore_index=True)

# %%
df3
# Out:
#         col1      col2      col3
# 0  -0.206500 -1.160823 -0.772992
# 1   1.163203 -2.917620 -0.297502
# 2  -0.269615 -1.262359 -1.370471
# 3  -0.223231 -0.133734  0.619062
# 4  -0.265080  1.750913  0.606281
# 5  -0.837831  0.892757  0.389634
# 6  -1.876066  1.441248  1.607121
# 7  -0.347523  0.958160  0.505948
# 8   1.525707  0.635860  1.355359
# 9  -0.175594  0.015363  0.808664
# 10  0.836250  0.070844 -1.074358
# 11  1.333872 -0.793309  0.690900
# 12 -0.590368 -0.548526 -0.314953
# 13  1.840619 -0.380707  1.198195
# 14  0.664352  0.492206 -0.266762
# 15 -0.570906  1.100950  0.772477
# 16  0.077875 -1.150067 -1.477893

# %%
for i in df3.col3:
  print(i)
# Out:
# -0.7729916345617109
# -0.29750248696616227
# -1.3704708327287636
# 0.6190624211750984
# 0.6062814231900037
# 0.3896339411509517
# 1.607121127246978
# 0.505947897205807
# 1.3553594639082973
# 0.8086643656874426
# -1.0743579903059255
# 0.6908995122631755
# -0.3149529035307691
# 1.1981953249149515
# -0.2667619928760673
# 0.7724770456509236
# -1.4778925318621694

# %% [markdown]
# * iteritems()

# %%
for key,value in df3.iteritems():
  print(key,value)
# Out:
# col1 0    -0.206500
# 1     1.163203
# 2    -0.269615
# 3    -0.223231
# 4    -0.265080
# 5    -0.837831
# 6    -1.876066
# 7    -0.347523
# 8     1.525707
# 9    -0.175594
# 10    0.836250
# 11    1.333872
# 12   -0.590368
# 13    1.840619
# 14    0.664352
# 15   -0.570906
# 16    0.077875
# Name: col1, dtype: float64
# col2 0    -1.160823
# 1    -2.917620
# 2    -1.262359
# 3    -0.133734
# 4     1.750913
# 5     0.892757
# 6     1.441248
# 7     0.958160
# 8     0.635860
# 9     0.015363
# 10    0.070844
# 11   -0.793309
# 12   -0.548526
# 13   -0.380707
# 14    0.492206
# 15    1.100950
# 16   -1.150067
# Name: col2, dtype: float64
# col3 0    -0.772992
# 1    -0.297502
# 2    -1.370471
# 3     0.619062
# 4     0.606281
# 5     0.389634
# 6     1.607121
# 7     0.505948
# 8     1.355359
# 9     0.808664
# 10   -1.074358
# 11    0.690900
# 12   -0.314953
# 13    1.198195
# 14   -0.266762
# 15    0.772477
# 16   -1.477893
# Name: col3, dtype: float64
# ...

# %% [markdown]
# * iterrows()

# %%
for index,row in df3.iterrows():
  print(index,row)
# Out:
# 0 col1   -0.206500
# col2   -1.160823
# col3   -0.772992
# Name: 0, dtype: float64
# 1 col1    1.163203
# col2   -2.917620
# col3   -0.297502
# Name: 1, dtype: float64
# 2 col1   -0.269615
# col2   -1.262359
# col3   -1.370471
# Name: 2, dtype: float64
# 3 col1   -0.223231
# col2   -0.133734
# col3    0.619062
# Name: 3, dtype: float64
# 4 col1   -0.265080
# col2    1.750913
# col3    0.606281
# Name: 4, dtype: float64
# 5 col1   -0.837831
# col2    0.892757
# col3    0.389634
# Name: 5, dtype: float64
# 6 col1   -1.876066
# col2    1.441248
# col3    1.607121
# Name: 6, dtype: float64
# 7 col1   -0.347523
# col2    0.958160
# col3    0.505948
# Name: 7, dtype: float64
# 8 col1    1.525707
# col2    0.635860
# col3    1.355359
# Name: 8, dtype: float64
# 9 col1   -0.175594
# col2    0.015363
# col3    0.808664
# Name: 9, dtype: float64
# 10 col1    0.836250
# col2    0.070844
# col3   -1.074358
# Name: 10, dtype: float64
# 11 col1    1.333872
# col2   -0.793309
# col3    0.690900
# ...

# %% [markdown]
# * sort_index()

# %%
unsorted_df = pd.DataFrame(np.random.randn(10,3),
                           index = [5,7,3,9,2,1,9,11,21,4],
                           columns = ['c1','c2','c3'])

# %%
unsorted_df
# Out:
#           c1        c2        c3
# 5   0.294066 -0.256786 -1.270529
# 7   1.471749 -0.883749 -0.476773
# 3  -1.034058  0.916761 -1.643962
# 9  -0.735014  0.447921  0.321347
# 2   1.506176  0.771442  0.320391
# 1  -0.187984 -0.049781 -1.474736
# 9  -0.133121  0.537227 -0.430860
# 11  0.441048  0.768733  0.760363
# 21 -1.173465 -0.597180 -0.271027
# 4  -0.497855 -0.626898  1.727891

# %%
unsorted_df.sort_index()
# Out:
#           c1        c2        c3
# 1  -0.187984 -0.049781 -1.474736
# 2   1.506176  0.771442  0.320391
# 3  -1.034058  0.916761 -1.643962
# 4  -0.497855 -0.626898  1.727891
# 5   0.294066 -0.256786 -1.270529
# 7   1.471749 -0.883749 -0.476773
# 9  -0.735014  0.447921  0.321347
# 9  -0.133121  0.537227 -0.430860
# 11  0.441048  0.768733  0.760363
# 21 -1.173465 -0.597180 -0.271027

# %%
unsorted_df.sort_index(ascending=False)
# Out:
#           c1        c2        c3
# 21 -1.173465 -0.597180 -0.271027
# 11  0.441048  0.768733  0.760363
# 9  -0.735014  0.447921  0.321347
# 9  -0.133121  0.537227 -0.430860
# 7   1.471749 -0.883749 -0.476773
# 5   0.294066 -0.256786 -1.270529
# 4  -0.497855 -0.626898  1.727891
# 3  -1.034058  0.916761 -1.643962
# 2   1.506176  0.771442  0.320391
# 1  -0.187984 -0.049781 -1.474736

# %%
unsorted_df.sort_index(ascending=False,axis=1)
# Out:
#           c3        c2        c1
# 5  -1.270529 -0.256786  0.294066
# 7  -0.476773 -0.883749  1.471749
# 3  -1.643962  0.916761 -1.034058
# 9   0.321347  0.447921 -0.735014
# 2   0.320391  0.771442  1.506176
# 1  -1.474736 -0.049781 -0.187984
# 9  -0.430860  0.537227 -0.133121
# 11  0.760363  0.768733  0.441048
# 21 -0.271027 -0.597180 -1.173465
# 4   1.727891 -0.626898 -0.497855

# %% [markdown]
# * sort_values()

# %%
df = pd.DataFrame({'Apple':[88,77,55,66,78],'Orange':[99,33,44,55,22]})
df
# Out:
#    Apple  Orange
# 0     88      99
# 1     77      33
# 2     55      44
# 3     66      55
# 4     78      22

# %%
df.sort_values(by=['Apple', 'Orange'])
# Out:
#    Apple  Orange
# 2     55      44
# 3     66      55
# 1     77      33
# 4     78      22
# 0     88      99

# %%
'''
1. Quicksort   -->default
2. Mergesort
3. Heapsort
'''

# %%
df.sort_values(by=['Apple'],kind="mergesort")
# Out:
#    Apple  Orange
# 2     55      44
# 3     66      55
# 1     77      33
# 4     78      22
# 0     88      99

# %% [markdown]
# * Advance statistics

# %%
df3
# Out:
#         col1      col2      col3
# 0  -0.206500 -1.160823 -0.772992
# 1   1.163203 -2.917620 -0.297502
# 2  -0.269615 -1.262359 -1.370471
# 3  -0.223231 -0.133734  0.619062
# 4  -0.265080  1.750913  0.606281
# 5  -0.837831  0.892757  0.389634
# 6  -1.876066  1.441248  1.607121
# 7  -0.347523  0.958160  0.505948
# 8   1.525707  0.635860  1.355359
# 9  -0.175594  0.015363  0.808664
# 10  0.836250  0.070844 -1.074358
# 11  1.333872 -0.793309  0.690900
# 12 -0.590368 -0.548526 -0.314953
# 13  1.840619 -0.380707  1.198195
# 14  0.664352  0.492206 -0.266762
# 15 -0.570906  1.100950  0.772477
# 16  0.077875 -1.150067 -1.477893

# %%
df4 = df3.drop([8,9,10,11,12,13,14,15,16])

# %%
df4
# Out:
#        col1      col2      col3
# 0 -0.206500 -1.160823 -0.772992
# 1  1.163203 -2.917620 -0.297502
# 2 -0.269615 -1.262359 -1.370471
# 3 -0.223231 -0.133734  0.619062
# 4 -0.265080  1.750913  0.606281
# 5 -0.837831  0.892757  0.389634
# 6 -1.876066  1.441248  1.607121
# 7 -0.347523  0.958160  0.505948

# %% [markdown]
# * cov --->covariance

# %%
df4.col2
# Out:
# 0   -1.160823
# 1   -2.917620
# 2   -1.262359
# 3   -0.133734
# 4    1.750913
# 5    0.892757
# 6    1.441248
# 7    0.958160
# Name: col2, dtype: float64

# %%
df4['col2']
# Out:
# 0   -1.160823
# 1   -2.917620
# 2   -1.262359
# 3   -0.133734
# 4    1.750913
# 5    0.892757
# 6    1.441248
# 7    0.958160
# Name: col2, dtype: float64

# %%
df4.cov
# Out:
# <bound method DataFrame.cov of        col1      col2      col3
# 0 -0.206500 -1.160823 -0.772992
# 1  1.163203 -2.917620 -0.297502
# 2 -0.269615 -1.262359 -1.370471
# 3 -0.223231 -0.133734  0.619062
# 4 -0.265080  1.750913  0.606281
# 5 -0.837831  0.892757  0.389634
# 6 -1.876066  1.441248  1.607121
# 7 -0.347523  0.958160  0.505948>

# %%
df4.col3.cov
# Out:
# <bound method Series.cov of 0   -0.772992
# 1   -0.297502
# 2   -1.370471
# 3    0.619062
# 4    0.606281
# 5    0.389634
# 6    1.607121
# 7    0.505948
# Name: col3, dtype: float64>

# %% [markdown]
# * corr -->correlation

# %%
df4.corr
# Out:
# <bound method DataFrame.corr of        col1      col2      col3
# 0 -0.206500 -1.160823 -0.772992
# 1  1.163203 -2.917620 -0.297502
# 2 -0.269615 -1.262359 -1.370471
# 3 -0.223231 -0.133734  0.619062
# 4 -0.265080  1.750913  0.606281
# 5 -0.837831  0.892757  0.389634
# 6 -1.876066  1.441248  1.607121
# 7 -0.347523  0.958160  0.505948>

# %%
df4['col2'].corr(df4['col3'])
# Out:
# 0.7280276489146803

# %% [markdown]
# # Data cleaning

# %%
df = pd.DataFrame(np.random.randn(5,3),
                  index=['A','E','B','C','D'],
                  columns=['col1','col2','col3']
                )

# %%
df
# Out:
#        col1      col2      col3
# A -1.067141  0.458195  2.312479
# E -1.038244 -0.451888 -0.297303
# B -0.834553 -0.047234  0.927071
# C  2.232202  0.548235  0.062711
# D -1.018370 -0.787298 -0.253622

# %% [markdown]
# reindex()

# %%
df = df.reindex(['A','B','Z','C','D','E','X','Y'])

# %%
df
# Out:
#        col1      col2      col3
# A -1.067141  0.458195  2.312479
# B -0.834553 -0.047234  0.927071
# Z       NaN       NaN       NaN
# C  2.232202  0.548235  0.062711
# D -1.018370 -0.787298 -0.253622
# E -1.038244 -0.451888 -0.297303
# X       NaN       NaN       NaN
# Y       NaN       NaN       NaN

# %% [markdown]
# * isnull()

# %%
df.isnull()
# Out:
#     col1   col2   col3
# A  False  False  False
# B  False  False  False
# Z   True   True   True
# C  False  False  False
# D  False  False  False
# E  False  False  False
# X   True   True   True
# Y   True   True   True

# %%
df['col3'].isnull()          # for columns
# Out:
# A    False
# B    False
# Z     True
# C    False
# D    False
# E    False
# X     True
# Y     True
# Name: col3, dtype: bool

# %%
df.loc['E'].isnull()      # for rows
# Out:
# col1    False
# col2    False
# col3    False
# Name: E, dtype: bool

# %%
df.isnull().sum()
# Out:
# col1    3
# col2    3
# col3    3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 9

# %%
df.isnull().sum(1)
# Out:
# A    0
# B    0
# Z    3
# C    0
# D    0
# E    0
# X    3
# Y    3
# dtype: int64

# %%
# same for isna() and notnull()

# %% [markdown]
# * isna()

# %%
df.isna()
# Out:
#     col1   col2   col3
# A  False  False  False
# B  False  False  False
# Z   True   True   True
# C  False  False  False
# D  False  False  False
# E  False  False  False
# X   True   True   True
# Y   True   True   True

# %% [markdown]
# * notnull()

# %%
df.notnull()
# Out:
#     col1   col2   col3
# A   True   True   True
# B   True   True   True
# Z  False  False  False
# C   True   True   True
# D   True   True   True
# E   True   True   True
# X  False  False  False
# Y  False  False  False

# %%
df.notnull().sum()
# Out:
# col1    5
# col2    5
# col3    5
# dtype: int64

# %% [markdown]
# * count()   --> gives no. of not NaN values in columns

# %%
df.count()
# Out:
# col1    5
# col2    5
# col3    5
# dtype: int64

# %% [markdown]
# fillna(obj)  --> cleans the all NaN values temporary

# %%
df
# Out:
#        col1      col2      col3
# A -1.067141  0.458195  2.312479
# B -0.834553 -0.047234  0.927071
# Z       NaN       NaN       NaN
# C  2.232202  0.548235  0.062711
# D -1.018370 -0.787298 -0.253622
# E -1.038244 -0.451888 -0.297303
# X       NaN       NaN       NaN
# Y       NaN       NaN       NaN

# %%
df.fillna(0)
# Out:
#        col1      col2      col3
# A -1.067141  0.458195  2.312479
# B -0.834553 -0.047234  0.927071
# Z  0.000000  0.000000  0.000000
# C  2.232202  0.548235  0.062711
# D -1.018370 -0.787298 -0.253622
# E -1.038244 -0.451888 -0.297303
# X  0.000000  0.000000  0.000000
# Y  0.000000  0.000000  0.000000

# %%
df
# Out:
#        col1      col2      col3
# A -1.067141  0.458195  2.312479
# B -0.834553 -0.047234  0.927071
# Z       NaN       NaN       NaN
# C  2.232202  0.548235  0.062711
# D -1.018370 -0.787298 -0.253622
# E -1.038244 -0.451888 -0.297303
# X       NaN       NaN       NaN
# Y       NaN       NaN       NaN

# %% [markdown]
#  Forward Method - pad/ffill
#
#  Backward Method - bfill/backfill

# %%
df.fillna(method='pad')
# Out:
#        col1      col2      col3
# A -1.067141  0.458195  2.312479
# B -0.834553 -0.047234  0.927071
# Z -0.834553 -0.047234  0.927071
# C  2.232202  0.548235  0.062711
# D -1.018370 -0.787298 -0.253622
# E -1.038244 -0.451888 -0.297303
# X -1.038244 -0.451888 -0.297303
# Y -1.038244 -0.451888 -0.297303

# %%
df.fillna(method='pad',axis=1)       # no change
# Out:
#        col1      col2      col3
# A -1.067141  0.458195  2.312479
# B -0.834553 -0.047234  0.927071
# Z       NaN       NaN       NaN
# C  2.232202  0.548235  0.062711
# D -1.018370 -0.787298 -0.253622
# E -1.038244 -0.451888 -0.297303
# X       NaN       NaN       NaN
# Y       NaN       NaN       NaN

# %%
df.fillna(method='bfill')
# Out:
#        col1      col2      col3
# A -1.067141  0.458195  2.312479
# B -0.834553 -0.047234  0.927071
# Z  2.232202  0.548235  0.062711
# C  2.232202  0.548235  0.062711
# D -1.018370 -0.787298 -0.253622
# E -1.038244 -0.451888 -0.297303
# X       NaN       NaN       NaN
# Y       NaN       NaN       NaN

# %% [markdown]
# * dropna()

# %%
df.dropna()
# Out:
#        col1      col2      col3
# A -1.067141  0.458195  2.312479
# B -0.834553 -0.047234  0.927071
# C  2.232202  0.548235  0.062711
# D -1.018370 -0.787298 -0.253622
# E -1.038244 -0.451888 -0.297303

# %%
df.dropna(1)
#each column containing NaN values get drop
# Out:
# <ipython-input-74-42a3c356049f>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df.dropna(1)
# Empty DataFrame
# Columns: []
# Index: [A, B, Z, C, D, E, X, Y]

# %%
df
# Out:
#        col1      col2      col3
# A -1.067141  0.458195  2.312479
# B -0.834553 -0.047234  0.927071
# Z       NaN       NaN       NaN
# C  2.232202  0.548235  0.062711
# D -1.018370 -0.787298 -0.253622
# E -1.038244 -0.451888 -0.297303
# X       NaN       NaN       NaN
# Y       NaN       NaN       NaN

# %% [markdown]
# * replace()

# %%
df = pd.DataFrame({'Apple':[88,77,55,66,78],'Orange':[99,33,44,55,22]})
df
# Out:
#    Apple  Orange
# 0     88      99
# 1     77      33
# 2     55      44
# 3     66      55
# 4     78      22

# %%
df.replace({88:888,44:444})
# Out:
#    Apple  Orange
# 0    888      99
# 1     77      33
# 2     55     444
# 3     66      55
# 4     78      22

# %%
df
# Out:
#    Apple  Orange
# 0     88      99
# 1     77      33
# 2     55      44
# 3     66      55
# 4     78      22

# %%
df.Apple.loc[4]=88

# %%
df
# Out:
#    Apple  Orange
# 0     88      99
# 1     77      33
# 2     55      44
# 3     66      55
# 4     88      22

# %% [markdown]
# # Handling Duplicates Values

# %% [markdown]
# * Check the duplicate values ->  duplicated()

# %%
df.duplicated()       #for checking duplicacy of rows
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated(subset=['Apple'])           #for checking duplicacy of columns
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# * Remove duplicate values -> drop_duplicates()

# %%
df
# Out:
#    Apple  Orange
# 0     88      99
# 1     77      33
# 2     55      44
# 3     66      55
# 4     88      22

# %%
df.drop_duplicates()
# Out:
#    Apple  Orange
# 0     88      99
# 1     77      33
# 2     55      44
# 3     66      55
# 4     88      22

# %%
df.drop_duplicates(subset=['Apple'])
# Out:
#    Apple  Orange
# 0     88      99
# 1     77      33
# 2     55      44
# 3     66      55

# %% [markdown]
# # Import/Export of Dataset

# %%
# Import
data = "https://raw.githubusercontent.com/ShapeAI/Python-for-Data-Science-/master/stocks.csv"
df = pd.read_csv(data)

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19   49.676899   51.693783   47.669952   49.845802   49.845802
# 1     2004-08-20   50.178635   54.187561   49.925285   53.805050   53.805050
# 2     2004-08-23   55.017166   56.373344   54.172661   54.346527   54.346527
# 3     2004-08-24   55.260582   55.439419   51.450363   52.096165   52.096165
# 4     2004-08-25   52.140873   53.651051   51.604362   52.657513   52.657513
# ...          ...         ...         ...         ...         ...         ...
# 3308  2017-10-09  980.000000  985.424988  976.109985  977.000000  977.000000
# 3309  2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#         Volume
# 0     44994500
# ...

# %%
# df.to_csv("name_of_the_new_file.csv","location")

# %% [markdown]
# nunique()  -> returns no. of unique values

# %%
df['Open'].nunique()
# Out:
# 3208

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3313 non-null   object
#  1   Open       3313 non-null   float64
#  2   High       3313 non-null   float64
#  3   Low        3313 non-null   float64
#  4   Close      3313 non-null   float64
#  5   Adj Close  3313 non-null   float64
#  6   Volume     3313 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 181.3+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
