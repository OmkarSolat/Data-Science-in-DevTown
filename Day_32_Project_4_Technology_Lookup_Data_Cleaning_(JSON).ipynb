# %% [markdown]
# <a href="https://colab.research.google.com/github/OmkarSolat/Data-Science-in-DevTown/blob/main/Day_32_Project_4_Technology_Lookup_Data_Cleaning_(JSON).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 4 -Technology Lookup Data Cleaning (JSON)
#
# Dataset (JSON): https://raw.githubusercontent.com/sahilrahman12/Technology-Lookup-Web-Application/main/technologies.json

# %% [markdown]
# # Importing Libraries

# %%
# Numpy
import numpy as np

# Pandas
import pandas as pd

# Matplotlib
import matplotlib.pyplot as plt

# Seaborn
import seaborn as sns

# RegEx (module)
import re

# %% [markdown]
# # Data Cleaning

# %%
tech = pd.read_json('https://raw.githubusercontent.com/sahilrahman12/Technology-Lookup-Web-Application/main/technologies.json')

# %%
data_tech = tech.copy()

# %%
data_tech.head()
# Out:
#                                                      1C-Bitrix  \
# cats                                                    [1, 6]
# description  1C-Bitrix is a system of web project managemen...
# headers      {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# html         (?:<link[^>]+components/bitrix|(?:src|href)="/...
# icon                                             1C-Bitrix.svg
#
#                                  3dCart @sulu/web          A-Frame  \
# cats                             [1, 6]      [59]             [25]
# description                         NaN       NaN              NaN
# headers      {'X-Powered-By': '3DCART'}       NaN              NaN
# html                                NaN       NaN  <a-scene[^<>]*>
# icon                         3dCart.png  Sulu.svg      A-Frame.svg
#
#                                                  A8.net  \
# cats                                               [71]
# description   A8.net is an affiliate marketing network.
# ...

# %%
data_tech.shape
# Out:
# (21, 1511)

# %% [markdown]
# 1. Manipulate the DataFrame in such a way that the column becomes the row and vice-versa

# %%
# Transpose
data_tech = data_tech.T

# %%
data_tech.head()
# Out:
#              cats                                        description  \
# 1C-Bitrix  [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart     [1, 6]                                                NaN
# @sulu/web    [59]                                                NaN
# A-Frame      [25]                                                NaN
# A8.net       [71]          A8.net is an affiliate marketing network.
#
#                                                      headers  \
# 1C-Bitrix  {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                            {'X-Powered-By': '3DCART'}
# @sulu/web                                                NaN
# A-Frame                                                  NaN
# A8.net                                                   NaN
#
#                                                         html           icon  \
# 1C-Bitrix  (?:<link[^>]+components/bitrix|(?:src|href)="/...  1C-Bitrix.svg
# ...

# %%
data_tech.shape
# Out:
# (1511, 21)

# %%
data_tech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1511 entries, 1C-Bitrix to xtCommerce
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cats         1511 non-null   object
#  1   description  776 non-null    object
#  2   headers      320 non-null    object
#  3   html         428 non-null    object
#  4   icon         1474 non-null   object
#  5   implies      482 non-null    object
#  6   scripts      679 non-null    object
#  7   website      1511 non-null   object
#  8   cookies      146 non-null    object
#  9   js           600 non-null    object
#  10  dom          60 non-null     object
#  11  pricing      213 non-null    object
#  12  saas         204 non-null    object
#  13  meta         272 non-null    object
#  14  cpe          195 non-null    object
#  15  certIssuer   5 non-null      object
#  16  url          51 non-null     object
#  17  oss          31 non-null     object
# ...

# %%
data_tech.columns
# Out:
# Index(['cats', 'description', 'headers', 'html', 'icon', 'implies', 'scripts',
#        'website', 'cookies', 'js', 'dom', 'pricing', 'saas', 'meta', 'cpe',
#        'certIssuer', 'url', 'oss', 'dns', 'excludes', 'css'],
#       dtype='object')

# %%
data_tech.headers.notnull().sum()
# Out:
# 320

# %%
data_tech.headers
# Out:
# 1C-Bitrix     {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                               {'X-Powered-By': '3DCART'}
# @sulu/web                                                   NaN
# A-Frame                                                     NaN
# A8.net                                                      NaN
#                                     ...
# wisyCMS                                                     NaN
# wpBakery                                                    NaN
# wpCache       {'X-Powered-By': 'wpCache(?:/([\d.]+))?\;versi...
# xCharts                                                     NaN
# xtCommerce                                                  NaN
# Name: headers, Length: 1511, dtype: object

# %%
# Getting Headers exception handling
for i in range(len(data_tech.headers)):
  try:
    key=data_tech.headers[i].keys()
    print(list(key))
  except:
    pass
# Out:
# ['Set-Cookie', 'X-Powered-CMS']
# ['X-Powered-By']
# ['Server']
# ['X-AH-Environment']
# ['X-Advertising-By']
# ['Cookie']
# ['X-Powered-By']
# ['X-Powered-By']
# ['Server']
# ['X-Akamai-Transformed', 'X-EdgeConnect-MidMile-RTT', 'X-EdgeConnect-Origin-MEX-Latency']
# ['X-Akaunting']
# ['Server']
# ['Server']
# ['Via', 'X-Amz-Cf-Id']
# ['Server']
# ['Server']
# ['server']
# ['X-Powered-By']
# ['Server']
# ['Server', 'X-Powered-By']
# ['Server']
# ['X-Powered-By']
# ['Arastta', 'X-Arastta']
# ['Server']
# ['AR-PoweredBy']
# ['X-Confluence-Request-Time']
# ['X-StatusPage-Skip-Logging', 'X-StatusPage-Version']
# ['X-Hacker']
# ['Server']
# ['azure-regionname', 'azure-sitename', 'azure-slotname', 'azure-version']
# ['X-EC-Debug', 'server']
# ['X-Supplied-By']
# ['X-Backdrop-Cache', 'X-Generator']
# ['X-Powered-By']
# ['CMS-Version']
# ['X-Powered-By']
# ['x-bubble-capacity-limit', 'x-bubble-capacity-used', 'x-bubble-perf']
# ['Server']
# ['X-Powered-By']
# ['Server', 'X-CF1', 'X-CF2']
# ...

# %%
# Getting unique values of headers column
arr = []
for i in range(len(data_tech.headers)):
  if not pd.isnull(data_tech.headers[i]):
    arr.extend(list(data_tech.headers[i].keys()))

# %%
arr = set(arr)

# %%
len(arr)
# Out:
# 185

# %%
data_tech
# Out:
#               cats                                        description  \
# 1C-Bitrix   [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart      [1, 6]                                                NaN
# @sulu/web     [59]                                                NaN
# A-Frame       [25]                                                NaN
# A8.net        [71]          A8.net is an affiliate marketing network.
# ...            ...                                                ...
# wisyCMS        [1]                                                NaN
# wpBakery      [51]  WPBakery is a drag and drop visual page builde...
# wpCache       [23]  WPCache is a static caching plugin for WordPress.
# xCharts       [25]                                                NaN
# xtCommerce     [6]                                                NaN
#
#                                                       headers  \
# 1C-Bitrix   {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# ...

# %% [markdown]
# * Converting the given url into the form of 'https://amazon.in'

# %%
# Input
url = "https://en.wikipedia.org/wiki/Avengers:_Endgame"

# %%
regex = "https://"+re.sub('.*//|/.*|www\.','',url)

# %%
regex
# Out:
# 'https://en.wikipedia.org'

# %% [markdown]
# * scrapping

# %%
# Importing Libraries

from bs4 import BeautifulSoup
import requests

# %%
req = requests.get(regex)

# %%
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-not-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
req.cookies.get_dict().keys()
# Out:
# dict_keys(['NetworkProbeLimit'])

# %%
data_tech
# Out:
#               cats                                        description  \
# 1C-Bitrix   [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart      [1, 6]                                                NaN
# @sulu/web     [59]                                                NaN
# A-Frame       [25]                                                NaN
# A8.net        [71]          A8.net is an affiliate marketing network.
# ...            ...                                                ...
# wisyCMS        [1]                                                NaN
# wpBakery      [51]  WPBakery is a drag and drop visual page builde...
# wpCache       [23]  WPCache is a static caching plugin for WordPress.
# xCharts       [25]                                                NaN
# xtCommerce     [6]                                                NaN
#
#                                                       headers  \
# 1C-Bitrix   {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# ...

# %% [markdown]
# # Data Analysis
